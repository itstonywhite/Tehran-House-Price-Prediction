# %% [markdown]
# # 🏠 Tehran House Price Prediction
#
# ## Project Overview
# This notebook predicts the price of a house given its features such as: Floor area, number of rooms, address, and the presence of parking, a warehouse, or an elevator.
